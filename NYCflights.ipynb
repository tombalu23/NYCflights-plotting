# %% [markdown]
# <a href="https://colab.research.google.com/github/tombalu23/NYCflights-plotting/blob/master/NYCflights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

flights=pd.read_csv('/gdrive/My Drive/Data_Lit/formatted_flights.csv')

#matplotlib histogram
plt.hist(flights['arr_delay'], color='blue', edgecolor='black', bins=int(180/5))

#seaborn histogram

#Add labels
plt.title('Histogram of arrival delays')
plt.xlabel('Delay(mins)')
plt.ylabel('No. of flights')
# Out:
# Text(0, 0.5, 'No. of flights')

# %%
plt.savefig('flights.png')

# %%
#using seaborn to plot histogram
#density 
arr_del=flights['arr_delay']
sns.distplot(flights['arr_delay'], bins=36, color='black', hist_kws={'edgecolor':'black'})

# %%
#count by airline name
sns.countplot(flights['arr_delay'],  data=flights, hue='name')
plt.legend(loc='upper right', prop={'size': 7})
plt.show()

# %%
airlines = ['United Air Lines Inc.', 'JetBlue Airways', 'ExpressJet Airlines Inc.',
         'Delta Air Lines Inc.', 'American Airlines Inc.', 'Alaska Airlines Inc.']

# Iterate through the six airlines
for airline in airlines:
   
    subset = flights[flights['name'] == airline]
    
    # Draw the density plot
    sns.distplot(subset['arr_delay'], hist = False, kde = True,
                 kde_kws = {'shade' : True,'linewidth': 3},
                 label = airline)
    
# Plot formatting
plt.legend(prop={'size': 9}, title = 'Airline')
plt.title('Density Plot with Multiple Airlines')
plt.xlabel('Delay (min)')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# We can see that Alaska Airlines is clearly earlier than the other airlines.
# My choice would be Alaska Airlines.
